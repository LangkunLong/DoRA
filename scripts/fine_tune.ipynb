# %% [markdown]
# ###Replicate commonsense reasoning tasks

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import torch
torch.cuda.empty_cache()

# %%
# !pwd
# !pip list
# Out:
# /content/DoRA/commonsense_reasoning
# Package                                  Version
# ---------------------------------------- ------------------
# absl-py                                  1.4.0
# accelerate                               0.26.1
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 23.2.1
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.17.2
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.12.1
# anywidget                                0.9.21
# appdirs                                  1.4.4
# apsw                                     3.51.1.0
# apswutils                                0.1.2
# argon2-cffi                              25.1.0
# argon2-cffi-bindings                     25.1.0
# array_record                             0.8.3
# arrow                                    1.4.0
# arviz                                    0.22.0
# astropy                                  7.2.0
# astropy-iers-data                        0.2026.1.5.0.43.43
# astunparse                               1.6.3
# atpublic                                 5.1
# attrs                                    25.4.0
# audioread                                3.1.0
# Authlib                                  1.6.6
# autograd                                 1.8.0
# babel                                    2.17.0
# backcall                                 0.2.0
# beartype                                 0.22.9
# beautifulsoup4                           4.13.5
# betterproto                              2.0.0b6
# bigframes                                2.31.0
# bigquery-magics                          0.10.3
# bitsandbytes                             0.49.1
# black                                    23.12.0
# bleach                                   6.3.0
# blinker                                  1.9.0
# blis                                     1.3.3
# blobfile                                 3.1.0
# blosc2                                   3.12.2
# bokeh                                    3.7.3
# Bottleneck                               1.4.2
# bqplot                                   0.12.45
# branca                                   0.8.2
# brotli                                   1.2.0
# CacheControl                             0.14.4
# cachetools                               6.2.4
# catalogue                                2.0.10
# certifi                                  2026.1.4
# cffi                                     2.0.0
# chardet                                  5.2.0
# charset-normalizer                       3.4.4
# chex                                     0.1.90
# clarabel                                 0.11.1
# click                                    8.3.1
# click-plugins                            1.1.1.2
# cligj                                    0.7.2
# cloudpathlib                             0.23.0
# cloudpickle                              3.1.2
# cmake                                    3.31.10
# cmdstanpy                                1.3.0
# colorcet                                 3.1.0
# colorlover                               0.3.0
# colour                                   0.1.5
# community                                1.0.0b1
# confection                               0.1.5
# cons                                     0.4.7
# contourpy                                1.3.3
# cramjam                                  2.11.0
# cryptography                             43.0.3
# cuda-bindings                            12.9.5
# cuda-core                                0.3.2
# cuda-pathfinder                          1.3.3
# cuda-python                              12.9.5
# cuda-toolkit                             12.9.1
# cudf-cu12                                25.10.0
# cudf-polars-cu12                         25.10.0
# cufflinks                                0.17.3
# cuml-cu12                                25.10.0
# cupy-cuda12x                             13.6.0
# curl_cffi                                0.14.0
# cvxopt                                   1.3.2
# cvxpy                                    1.6.7
# cycler                                   0.12.1
# cyipopt                                  1.5.0
# cymem                                    2.0.13
# Cython                                   3.0.12
# dask                                     2025.9.1
# dask-cuda                                25.10.0
# dask-cudf-cu12                           25.10.0
# dataproc-spark-connect                   1.0.1
# datasets                                 2.15.0
# db-dtypes                                1.5.0
# dbus-python                              1.2.18
# debugpy                                  1.8.15
# decorator                                4.4.2
# defusedxml                               0.7.1
# deprecation                              2.1.0
# diffusers                                0.36.0
# dill                                     0.3.7
# distributed                              2025.9.1
# distributed-ucxx-cu12                    0.46.0
# distro                                   1.9.0
# dlib                                     19.24.6
# dm-tree                                  0.1.9
# docstring_parser                         0.17.0
# docutils                                 0.21.2
# dopamine_rl                              4.1.2
# duckdb                                   1.3.2
# earthengine-api                          1.5.24
# easydict                                 1.13
# editdistance                             0.8.1
# eerepr                                   0.1.2
# einops                                   0.8.1
# en_core_web_sm                           3.8.0
# entrypoints                              0.4
# esda                                     2.8.1
# et_xmlfile                               2.0.0
# etils                                    1.13.0
# etuples                                  0.3.10
# Farama-Notifications                     0.0.4
# fastai                                   2.8.6
# fastapi                                  0.123.10
# fastcore                                 1.11.2
# fastdownload                             0.0.7
# fastjsonschema                           2.21.2
# fastlite                                 0.2.3
# fastprogress                             1.1.3
# fastrlock                                0.8.3
# fasttransform                            0.0.2
# ffmpy                                    1.0.0
# filelock                                 3.20.2
# fiona                                    1.10.1
# fire                                     0.5.0
# firebase-admin                           6.9.0
# Flask                                    3.1.2
# flatbuffers                              25.12.19
# flax                                     0.10.7
# folium                                   0.20.0
# fonttools                                4.61.1
# fqdn                                     1.5.1
# frozendict                               2.4.7
# frozenlist                               1.8.0
# fsspec                                   2023.10.0
# future                                   1.0.0
# gast                                     0.7.0
# gcsfs                                    2025.3.0
# GDAL                                     3.8.4
# gdown                                    5.2.0
# geemap                                   0.35.3
# geocoder                                 1.38.1
# geographiclib                            2.1
# geopandas                                1.1.2
# geopy                                    2.4.1
# giddy                                    2.3.8
# gin-config                               0.5.0
# gitdb                                    4.0.12
# GitPython                                3.1.46
# glob2                                    0.7
# google                                   3.0.0
# google-adk                               1.21.0
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.29.0
# google-api-python-client                 2.187.0
# google-auth                              2.43.0
# google-auth-httplib2                     0.3.0
# google-auth-oauthlib                     1.2.2
# google-cloud-aiplatform                  1.130.0
# google-cloud-appengine-logging           1.7.0
# google-cloud-audit-log                   0.4.0
# google-cloud-bigquery                    3.40.0
# google-cloud-bigquery-connection         1.19.0
# google-cloud-bigquery-storage            2.36.0
# google-cloud-bigtable                    2.35.0
# google-cloud-core                        2.5.0
# google-cloud-dataproc                    5.23.0
# google-cloud-datastore                   2.23.0
# google-cloud-discoveryengine             0.13.12
# google-cloud-firestore                   2.22.0
# google-cloud-functions                   1.21.0
# google-cloud-language                    2.18.0
# google-cloud-logging                     3.13.0
# google-cloud-monitoring                  2.28.0
# google-cloud-resource-manager            1.15.0
# google-cloud-secret-manager              2.26.0
# google-cloud-spanner                     3.61.0
# google-cloud-speech                      2.35.0
# google-cloud-storage                     3.7.0
# google-cloud-trace                       1.17.0
# google-cloud-translate                   3.23.0
# google-colab                             1.0.0
# google-crc32c                            1.8.0
# google-genai                             1.55.0
# google-generativeai                      0.8.6
# google-pasta                             0.2.0
# google-resumable-media                   2.8.0
# googleapis-common-protos                 1.72.0
# googledrivedownloader                    1.1.0
# gradio                                   4.9.0
# gradio_client                            0.7.2
# graphviz                                 0.21
# greenlet                                 3.3.0
# groovy                                   0.1.2
# grpc-google-iam-v1                       0.14.3
# grpc-interceptor                         0.15.4
# grpcio                                   1.76.0
# grpcio-status                            1.71.2
# grpclib                                  0.4.9
# gspread                                  6.2.1
# gspread-dataframe                        4.0.0
# gym                                      0.25.2
# gym-notices                              0.1.0
# gymnasium                                1.2.3
# h11                                      0.16.0
# h2                                       4.3.0
# h5netcdf                                 1.7.3
# h5py                                     3.15.1
# hdbscan                                  0.8.41
# hf_transfer                              0.1.9
# hf-xet                                   1.2.0
# highspy                                  1.12.0
# holidays                                 0.88
# holoviews                                1.22.1
# hpack                                    4.1.0
# html5lib                                 1.1
# httpcore                                 1.0.9
# httpimport                               1.4.1
# httplib2                                 0.31.0
# httptools                                0.7.1
# httpx                                    0.28.1
# httpx-sse                                0.4.3
# huggingface-hub                          0.36.0
# humanize                                 4.15.0
# hyperframe                               6.1.0
# hyperopt                                 0.2.7
# ibis-framework                           9.5.0
# idna                                     3.11
# ImageIO                                  2.37.2
# imageio-ffmpeg                           0.6.0
# imagesize                                1.4.1
# imbalanced-learn                         0.14.1
# immutabledict                            4.2.2
# importlib_metadata                       8.7.1
# importlib_resources                      6.5.2
# imutils                                  0.5.4
# inequality                               1.1.2
# inflect                                  7.5.0
# iniconfig                                2.3.0
# intel-cmplr-lib-ur                       2025.3.1
# intel-openmp                             2025.3.1
# ipyevents                                2.0.4
# ipyfilechooser                           0.6.0
# ipykernel                                6.17.1
# ipyleaflet                               0.20.0
# ipyparallel                              8.8.0
# ipython                                  7.34.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipytree                                  0.2.2
# ipywidgets                               7.7.1
# isoduration                              20.11.0
# itsdangerous                             2.2.0
# jaraco.classes                           3.4.0
# jaraco.context                           6.0.2
# jaraco.functools                         4.4.0
# jax                                      0.7.2
# jax-cuda12-pjrt                          0.7.2
# jax-cuda12-plugin                        0.7.2
# jaxlib                                   0.7.2
# jedi                                     0.19.2
# jeepney                                  0.9.0
# jieba                                    0.42.1
# Jinja2                                   3.1.6
# jiter                                    0.12.0
# joblib                                   1.5.3
# jsonpatch                                1.33
# jsonpickle                               4.1.1
# jsonpointer                              3.0.0
# jsonschema                               4.26.0
# jsonschema-specifications                2025.9.1
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.9.1
# jupyter-events                           0.12.0
# jupyter_kernel_gateway                   2.5.2
# jupyter-leaflet                          0.20.0
# jupyter_server                           2.14.0
# jupyter_server_terminals                 0.5.3
# jupyterlab_pygments                      0.3.0
# jupyterlab_widgets                       3.0.16
# jupytext                                 1.18.1
# kaggle                                   1.7.4.5
# kagglehub                                0.3.13
# keras                                    3.10.0
# keras-hub                                0.21.1
# keras-nlp                                0.21.1
# keyring                                  25.7.0
# keyrings.google-artifactregistry-auth    1.1.2
# kiwisolver                               1.4.9
# langchain                                1.2.3
# langchain-core                           1.2.6
# langgraph                                1.0.5
# langgraph-checkpoint                     3.0.1
# langgraph-prebuilt                       1.0.5
# langgraph-sdk                            0.3.1
# langsmith                                0.6.1
# lark                                     1.3.1
# launchpadlib                             1.10.16
# lazr.restfulclient                       0.14.4
# lazr.uri                                 1.0.6
# lazy_loader                              0.4
# libclang                                 18.1.1
# libcudf-cu12                             25.10.0
# libcugraph-cu12                          25.10.1
# libcuml-cu12                             25.10.0
# libkvikio-cu12                           25.10.0
# libpysal                                 4.14.0
# libraft-cu12                             25.10.0
# librmm-cu12                              25.10.0
# librosa                                  0.11.0
# libucx-cu12                              1.19.0
# libucxx-cu12                             0.46.0
# lightgbm                                 4.6.0
# linkify-it-py                            2.0.3
# llvmlite                                 0.43.0
# locket                                   1.0.0
# logical-unification                      0.4.7
# lxml                                     6.0.2
# Mako                                     1.3.10
# mapclassify                              2.10.0
# Markdown                                 3.10
# markdown-it-py                           4.0.0
# MarkupSafe                               2.1.5
# matplotlib                               3.10.0
# matplotlib-inline                        0.2.1
# matplotlib-venn                          1.1.2
# mcp                                      1.25.0
# mdit-py-plugins                          0.5.0
# mdurl                                    0.1.2
# mgwr                                     2.2.1
# miniKanren                               1.0.5
# missingno                                0.5.2
# mistune                                  3.2.0
# mizani                                   0.13.5
# mkl                                      2025.3.0
# ml_dtypes                                0.5.4
# mlxtend                                  0.23.4
# mmh3                                     5.2.0
# momepy                                   0.11.0
# more-itertools                           10.8.0
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# msgpack                                  1.1.2
# multidict                                6.7.0
# multipledispatch                         1.0.0
# multiprocess                             0.70.15
# multitasking                             0.0.12
# murmurhash                               1.0.15
# music21                                  9.9.1
# mypy_extensions                          1.1.0
# namex                                    0.1.0
# narwhals                                 2.15.0
# natsort                                  8.4.0
# nbclassic                                1.3.3
# nbclient                                 0.10.4
# nbconvert                                7.16.6
# nbformat                                 5.10.4
# ndindex                                  1.10.1
# nest-asyncio                             1.6.0
# networkx                                 3.6.1
# nibabel                                  5.3.3
# nltk                                     3.9.1
# notebook                                 6.5.7
# notebook_shim                            0.2.4
# numba                                    0.60.0
# numba-cuda                               0.19.1
# numexpr                                  2.14.1
# numpy                                    1.26.4
# nvidia-cublas-cu12                       12.6.4.1
# nvidia-cuda-cccl-cu12                    12.9.27
# nvidia-cuda-cupti-cu12                   12.6.80
# nvidia-cuda-nvcc-cu12                    12.5.82
# nvidia-cuda-nvrtc-cu12                   12.6.77
# nvidia-cuda-runtime-cu12                 12.6.77
# nvidia-cudnn-cu12                        9.10.2.21
# nvidia-cufft-cu12                        11.3.0.4
# nvidia-cufile-cu12                       1.11.1.6
# nvidia-curand-cu12                       10.3.7.77
# nvidia-cusolver-cu12                     11.7.1.2
# nvidia-cusparse-cu12                     12.5.4.2
# nvidia-cusparselt-cu12                   0.7.1
# nvidia-ml-py                             13.590.44
# nvidia-nccl-cu12                         2.27.5
# nvidia-nvjitlink-cu12                    12.6.85
# nvidia-nvshmem-cu12                      3.3.20
# nvidia-nvtx-cu12                         12.6.77
# nvtx                                     0.2.14
# nx-cugraph-cu12                          25.10.0
# oauth2client                             4.1.3
# oauthlib                                 3.3.1
# omegaconf                                2.3.0
# onemkl-license                           2025.3.0
# openai                                   2.14.0
# opencv-contrib-python                    4.12.0.88
# opencv-python                            4.12.0.88
# opencv-python-headless                   4.12.0.88
# openpyxl                                 3.1.5
# opentelemetry-api                        1.37.0
# opentelemetry-exporter-gcp-logging       1.11.0a0
# opentelemetry-exporter-gcp-monitoring    1.11.0a0
# opentelemetry-exporter-gcp-trace         1.11.0
# opentelemetry-exporter-otlp-proto-common 1.37.0
# opentelemetry-exporter-otlp-proto-http   1.37.0
# opentelemetry-proto                      1.37.0
# opentelemetry-resourcedetector-gcp       1.11.0a0
# opentelemetry-sdk                        1.37.0
# opentelemetry-semantic-conventions       0.58b0
# opt_einsum                               3.4.0
# optax                                    0.2.6
# optree                                   0.18.0
# orbax-checkpoint                         0.11.31
# orjson                                   3.11.5
# ormsgpack                                1.12.1
# osqp                                     1.0.5
# overrides                                7.7.0
# packaging                                25.0
# pandas                                   2.2.2
# pandas-datareader                        0.10.0
# pandas-gbq                               0.30.0
# pandas-stubs                             2.2.2.240909
# pandocfilters                            1.5.1
# panel                                    1.8.5
# param                                    2.3.1
# parso                                    0.8.5
# parsy                                    2.2
# partd                                    1.4.2
# pathspec                                 1.0.3
# patsy                                    1.0.2
# peewee                                   3.19.0
# pexpect                                  4.9.0
# pickleshare                              0.7.5
# pillow                                   10.4.0
# pip                                      24.1.2
# platformdirs                             4.5.1
# plotly                                   5.24.1
# plotnine                                 0.14.5
# pluggy                                   1.6.0
# plum-dispatch                            2.6.1
# ply                                      3.11
# pointpats                                2.5.2
# polars                                   1.31.0
# pooch                                    1.8.2
# portpicker                               1.5.2
# preshed                                  3.0.12
# prettytable                              3.17.0
# proglog                                  0.1.12
# progressbar2                             4.5.0
# prometheus_client                        0.23.1
# promise                                  2.3
# prompt_toolkit                           3.0.52
# propcache                                0.4.1
# prophet                                  1.2.1
# proto-plus                               1.27.0
# protobuf                                 5.29.5
# psutil                                   5.9.5
# psycopg2                                 2.9.11
# psygnal                                  0.15.1
# ptyprocess                               0.7.0
# PuLP                                     3.3.0
# py-cpuinfo                               9.0.0
# py4j                                     0.10.9.9
# pyarrow                                  18.1.0
# pyarrow-hotfix                           0.7
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.2
# pycairo                                  1.29.0
# pycocotools                              2.0.11
# pycparser                                2.23
# pycryptodomex                            3.23.0
# pydantic                                 2.12.3
# pydantic_core                            2.41.4
# pydantic-settings                        2.12.0
# pydata-google-auth                       1.9.1
# pydot                                    4.0.1
# pydotplus                                2.0.2
# PyDrive2                                 1.21.3
# pydub                                    0.25.1
# pyerfa                                   2.0.1.5
# pygame                                   2.6.1
# pygit2                                   1.19.1
# Pygments                                 2.19.2
# PyGObject                                3.48.2
# PyJWT                                    2.10.1
# pylibcudf-cu12                           25.10.0
# pylibcugraph-cu12                        25.10.1
# pylibraft-cu12                           25.10.0
# pymc                                     5.27.0
# pynndescent                              0.6.0
# pyogrio                                  0.12.1
# pyomo                                    6.9.5
# PyOpenGL                                 3.1.10
# pyOpenSSL                                24.2.1
# pyparsing                                3.3.1
# pyperclip                                1.11.0
# pyproj                                   3.7.2
# pysal                                    25.7
# pyshp                                    3.0.3
# PySocks                                  1.7.1
# pyspark                                  4.0.1
# pytensor                                 2.36.3
# pytest                                   8.4.2
# python-apt                               0.0.0
# python-box                               7.3.2
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.2.1
# python-fasthtml                          0.12.37
# python-json-logger                       4.0.0
# python-louvain                           0.16
# python-multipart                         0.0.21
# python-slugify                           8.0.4
# python-snappy                            0.7.3
# python-utils                             3.9.1
# pytz                                     2025.2
# pyviz_comms                              3.0.6
# PyWavelets                               1.9.0
# PyYAML                                   6.0.3
# pyzmq                                    26.2.1
# quantecon                                0.10.1
# raft-dask-cu12                           25.10.0
# rapids-dask-dependency                   25.10.0
# rapids-logger                            0.1.19
# rasterio                                 1.5.0
# rasterstats                              0.20.0
# ratelim                                  0.1.6
# referencing                              0.37.0
# regex                                    2025.11.3
# requests                                 2.32.4
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# requirements-parser                      0.9.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rfc3987-syntax                           1.1.0
# rich                                     13.9.4
# rmm-cu12                                 25.10.0
# roman-numerals                           4.1.0
# roman-numerals-py                        4.1.0
# rpds-py                                  0.30.0
# rpy2                                     3.5.17
# rsa                                      4.9.1
# rtree                                    1.4.1
# ruff                                     0.14.11
# safehttpx                                0.1.7
# safetensors                              0.7.0
# scikit-image                             0.25.2
# scikit-learn                             1.6.1
# scipy                                    1.11.4
# scooby                                   0.11.0
# scs                                      3.2.10
# seaborn                                  0.13.2
# SecretStorage                            3.5.0
# segregation                              2.5.3
# semantic-version                         2.10.0
# Send2Trash                               2.0.0
# sentence-transformers                    5.2.0
# sentencepiece                            0.1.99
# sentry-sdk                               2.49.0
# setuptools                               75.2.0
# shap                                     0.50.0
# shapely                                  2.1.2
# shellingham                              1.5.4
# simple-parsing                           0.1.7
# simplejson                               3.20.2
# simsimd                                  6.5.12
# six                                      1.17.0
# sklearn-compat                           0.1.5
# sklearn-pandas                           2.2.0
# slicer                                   0.0.8
# smart_open                               7.5.0
# smmap                                    5.0.2
# sniffio                                  1.3.1
# snowballstemmer                          3.0.1
# sortedcontainers                         2.4.0
# soundfile                                0.13.1
# soupsieve                                2.8.1
# soxr                                     1.0.0
# spacy                                    3.8.11
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# spaghetti                                1.7.6
# spanner-graph-notebook                   1.1.8
# spglm                                    1.1.0
# Sphinx                                   8.2.3
# sphinxcontrib-applehelp                  2.0.0
# sphinxcontrib-devhelp                    2.0.0
# sphinxcontrib-htmlhelp                   2.1.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     2.0.0
# sphinxcontrib-serializinghtml            2.0.0
# spint                                    1.0.7
# splot                                    1.1.7
# spopt                                    0.7.0
# spreg                                    1.8.4
# SQLAlchemy                               2.0.45
# sqlalchemy-spanner                       1.17.2
# sqlglot                                  25.20.2
# sqlparse                                 0.5.5
# srsly                                    2.5.2
# sse-starlette                            3.1.2
# stanio                                   0.5.1
# starlette                                0.50.0
# statsmodels                              0.14.6
# stringzilla                              4.6.0
# stumpy                                   1.13.0
# sympy                                    1.14.0
# tables                                   3.10.2
# tabulate                                 0.9.0
# tbb                                      2022.3.0
# tblib                                    3.2.2
# tcmlib                                   1.4.1
# tenacity                                 9.1.2
# tensorboard                              2.19.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.19.0
# tensorflow-datasets                      4.9.9
# tensorflow_decision_forests              1.12.0
# tensorflow-hub                           0.16.1
# tensorflow-metadata                      1.17.2
# tensorflow-probability                   0.25.0
# tensorflow-text                          2.19.0
# tensorstore                              0.1.80
# termcolor                                3.3.0
# terminado                                0.18.1
# text-unidecode                           1.3
# textblob                                 0.19.0
# tf_keras                                 2.19.0
# tf-slim                                  1.1.0
# thinc                                    8.3.10
# threadpoolctl                            3.6.0
# tifffile                                 2025.12.20
# tiktoken                                 0.12.0
# timm                                     1.0.24
# tinycss2                                 1.4.0
# tobler                                   0.13.0
# tokenize_rt                              6.2.0
# tokenizers                               0.15.2
# toml                                     0.10.2
# tomlkit                                  0.12.0
# toolz                                    0.12.1
# torch                                    2.9.0+cu126
# torchao                                  0.10.0
# torchaudio                               2.9.0+cu126
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.24.0+cu126
# tornado                                  6.5.1
# tqdm                                     4.67.1
# traitlets                                5.7.1
# traittypes                               0.2.3
# transformers                             4.36.0
# treelite                                 4.4.1
# treescope                                0.1.10
# triton                                   3.5.0
# tsfresh                                  0.21.1
# tweepy                                   4.16.0
# typeguard                                4.4.4
# typer                                    0.21.1
# typer-slim                               0.21.1
# types-pytz                               2025.2.0.20251108
# types-setuptools                         80.9.0.20250822
# typing_extensions                        4.15.0
# typing-inspection                        0.4.2
# tzdata                                   2025.3
# tzlocal                                  5.3.1
# uc-micro-py                              1.0.3
# ucxx-cu12                                0.46.0
# umap-learn                               0.5.9.post2
# umf                                      1.0.2
# uri-template                             1.3.0
# uritemplate                              4.2.0
# urllib3                                  2.5.0
# uuid_utils                               0.13.0
# uvicorn                                  0.40.0
# uvloop                                   0.22.1
# vega-datasets                            0.9.0
# wadllib                                  1.3.6
# wandb                                    0.23.1
# wasabi                                   1.1.3
# watchdog                                 6.0.0
# watchfiles                               1.1.1
# wcwidth                                  0.2.14
# weasel                                   0.4.3
# webcolors                                25.10.0
# webencodings                             0.5.1
# websocket-client                         1.9.0
# websockets                               11.0.3
# Werkzeug                                 3.1.5
# wheel                                    0.45.1
# widgetsnbextension                       3.6.10
# wordcloud                                1.9.5
# wrapt                                    2.0.1
# wurlitzer                                3.1.1
# xarray                                   2025.12.0
# xarray-einstats                          0.9.1
# xgboost                                  3.1.2
# xlrd                                     2.0.2
# xxhash                                   3.6.0
# xyzservices                              2025.11.0
# yarl                                     1.22.0
# ydf                                      0.13.0
# yellowbrick                              1.5
# yfinance                                 0.2.66
# zict                                     3.0.0
# zipp                                     3.23.0
# zstandard                                0.25.0

# %%
# !nvidia-smi
# Out:
# Thu Jan 15 23:06:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !git clone https://github.com/NVlabs/DoRA.git
# %cd /content/DoRA/commonsense_reasoning


# !pip uninstall peft bitsandbytes -y
# Out:
# fatal: destination path 'DoRA' already exists and is not an empty directory.
# /content/DoRA/commonsense_reasoning
# WARNING: Skipping peft as it is not installed.
# Found existing installation: bitsandbytes 0.49.1
# Uninstalling bitsandbytes-0.49.1:
#   Successfully uninstalled bitsandbytes-0.49.1

# %%
# !pip install -r requirements.txt

# for cuda and memory cache clear
# !pip install bitsandbytes --upgrade
# !pip install accelerate==0.26.1
# Out:
# Collecting git+https://github.com/huggingface/transformers.git@v4.36.0 (from -r requirements.txt (line 8))
#   Cloning https://github.com/huggingface/transformers.git (to revision v4.36.0) to /tmp/pip-req-build-1cx0yejt
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-1cx0yejt
#   Running command git checkout -q 6da8b7cbc9ded50361b0428a5725d9b9410ca169
#   Resolved https://github.com/huggingface/transformers.git to commit 6da8b7cbc9ded50361b0428a5725d9b9410ca169
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate==0.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: appdirs==1.4.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.4.4)
# Collecting bitsandbytes==0.41.3.post2 (from -r requirements.txt (line 3))
#   Using cached bitsandbytes-0.41.3.post2-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: black==23.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (23.12.0)
# Requirement already satisfied: datasets==2.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: fire==0.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.5.0)
# Requirement already satisfied: gradio==4.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: scipy==1.11.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.11.4)
# Requirement already satisfied: sentencepiece==0.1.99 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (5.29.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (2.9.0+cu126)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (0.36.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.25.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black==23.12.0->-r requirements.txt (line 4)) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black==23.12.0->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from black==23.12.0->-r requirements.txt (line 4)) (1.0.3)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black==23.12.0->-r requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: aiohttp>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from black==23.12.0->-r requirements.txt (line 4)) (3.13.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (0.7)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.15.0->-r requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.15.0->-r requirements.txt (line 6)) (2023.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from fire==0.5.0->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire==0.5.0->-r requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: gradio-client==0.7.2 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (3.11.5)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.0.21)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /usr/local/lib/python3.12/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.9.0->-r requirements.txt (line 9)) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.9.0->-r requirements.txt (line 9)) (0.40.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==0.7.2->gradio==4.9.0->-r requirements.txt (line 9)) (11.0.3)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.12/dist-packages (from black[jupyter]->-r requirements.txt (line 5)) (7.34.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from black[jupyter]->-r requirements.txt (line 5)) (6.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.0->-r requirements.txt (line 8)) (3.20.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.0->-r requirements.txt (line 8)) (2025.11.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers==4.36.0->-r requirements.txt (line 8)) (0.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.7.4->black==23.12.0->-r requirements.txt (line 4)) (1.22.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==4.9.0->-r requirements.txt (line 9)) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==4.9.0->-r requirements.txt (line 9)) (2.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.25.0->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.9.0->-r requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.9.0->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.9.0->-r requirements.txt (line 9)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.9.0->-r requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.9.0->-r requirements.txt (line 9)) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.9.0->-r requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.15.0->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.15.0->-r requirements.txt (line 6)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.9.0->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.9.0->-r requirements.txt (line 9)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.9.0->-r requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.15.0->-r requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.15.0->-r requirements.txt (line 6)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.15.0->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.15.0->-r requirements.txt (line 6)) (2026.1.4)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.9.0->-r requirements.txt (line 9)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.9.0->-r requirements.txt (line 9)) (13.9.4)
# WARNING: typer 0.21.1 does not provide the extra 'all'
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.14.0->gradio==4.9.0->-r requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==4.9.0->-r requirements.txt (line 9)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==4.9.0->-r requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->gradio==4.9.0->-r requirements.txt (line 9)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->gradio==4.9.0->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.9.0->-r requirements.txt (line 9)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.9.0->-r requirements.txt (line 9)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.9.0->-r requirements.txt (line 9)) (0.30.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.8.0->black[jupyter]->-r requirements.txt (line 5)) (0.2.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.9.0->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==0.25.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.9.0->-r requirements.txt (line 9)) (0.1.2)
# Using cached bitsandbytes-0.41.3.post2-py3-none-any.whl (92.6 MB)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.41.3.post2
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.41.3.post2)
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (2.1.5)
# Using cached bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
# Installing collected packages: bitsandbytes
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.41.3.post2
#     Uninstalling bitsandbytes-0.41.3.post2:
#       Successfully uninstalled bitsandbytes-0.41.3.post2
# Successfully installed bitsandbytes-0.49.1
# Collecting accelerate==0.26.1
#   Downloading accelerate-0.26.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (6.0.3)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (2.9.0+cu126)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (0.36.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.26.1) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.26.1) (3.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.26.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.26.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.26.1) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==0.26.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.26.1) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.26.1) (2026.1.4)
# Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.25.0
#     Uninstalling accelerate-0.25.0:
#       Successfully uninstalled accelerate-0.25.0
# Successfully installed accelerate-0.26.1

# %% [markdown]
# ###170k finetuning dataset

# %%
# !rm commonsense_170k.json
# !wget https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/ft-training_set/commonsense_170k.json -O commonsense_170k.json

if os.path.exists("commonsense_170k.json"):
    print("Dataset downloaded successfully!")
else:
    print("Error: Dataset download failed.")
# Out:
# rm: cannot remove 'commonsense_170k.json': No such file or directory
# --2026-01-15 23:07:47--  https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/ft-training_set/commonsense_170k.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96529722 (92M) [text/plain]
# Saving to: ‘commonsense_170k.json’
#
# commonsense_170k.js 100%[===================>]  92.06M   248MB/s    in 0.4s
#
# 2026-01-15 23:07:48 (248 MB/s) - ‘commonsense_170k.json’ saved [96529722/96529722]
#
# Dataset downloaded successfully!

# %% [markdown]
# ### Evaluation dataset

# %%
base_dir = "/content/DoRA/commonsense_reasoning/dataset"
os.makedirs(base_dir, exist_ok=True)

tasks = {
    "boolq": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/boolq/test.json",
    "piqa": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/piqa/test.json",
    "social_iqa": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/social_iqa/test.json",
    "hellaswag": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/hellaswag/test.json",
    "winogrande": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/winogrande/test.json",
    "ARC-Easy": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/ARC-Easy/test.json",
    "ARC-Challenge": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/ARC-Challenge/test.json",
    "openbookqa": "https://raw.githubusercontent.com/AGI-Edgerunners/LLM-Adapters/main/dataset/openbookqa/test.json"
}

for task, url in tasks.items():
    task_dir = os.path.join(base_dir, task)
    os.makedirs(task_dir, exist_ok=True)
    output_file = os.path.join(task_dir, "test.json")

    print(f"Downloading {task}...")
    # !wget -q {url} -O {output_file}
# Out:
# Downloading boolq...
# Downloading piqa...
# Downloading social_iqa...
# Downloading hellaswag...
# Downloading winogrande...
# Downloading ARC-Easy...
# Downloading ARC-Challenge...
# Downloading openbookqa...

# %% [markdown]
# ###Hyperparameters
# Llama -7B \
# rank r: 16 (to save memory and compute) \
# alpha: 64 \
# dropout: 0.05 \
# optimizer: adam \
# lr: 2e-4, 1e-4 \
# lr scheduler: linear \
# batch: 16 \
# warmup: 100 \
# epochs: 3 \
# wahere: Q, K, V, Up, Down

# %%
# %cd /content/DoRA/commonsense_reasoning
# !chmod +x *.sh
# Out:
# /content/DoRA/commonsense_reasoning

# %% [markdown]
# ###Finetuning

# %%
# LLama 7B, using micro batch size 8 to save memory (out of bounds on A100)
# !python finetune.py \
    --base_model 'yahma/llama-7b-hf' \
    --data_path 'commonsense_170k.json' \
    --output_dir './finetuned_result/dora_r16' \
    --batch_size 16 --micro_batch_size 8 --num_epochs 3 \
    --learning_rate 2e-4 --cutoff_len 256 --val_set_size 120 \
    --eval_step 80 --save_step 80 --adapter_name dora \
    --target_modules '["q_proj", "k_proj", "v_proj", "up_proj", "down_proj"]' \
    --lora_r 16 --lora_alpha 64 --use_gradient_checkpointing
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Finetuning model with params:
# base_model: yahma/llama-7b-hf
# data_path: commonsense_170k.json
# output_dir: ./finetuned_result/dora_r16
# batch_size: 16
# micro_batch_size: 8
# num_epochs: 3
# learning_rate: 0.0002
# cutoff_len: 256
# val_set_size: 120
# use_gradient_checkpointing: True
# lora_r: 16
# lora_alpha: 64
# lora_dropout: 0.05
# lora_target_modules: None
# Wdecompose_target_modules: None
# dora_simple: Truebottleneck_size: 256
# non_linearity: tanh
# adapter_dropout: 0.0
# use_parallel_adapter: False
# use_adapterp: False
# train_on_inputs: True
# scaling: 1.0
# adapter_name: dora
# target_modules: ['q_proj', 'k_proj', 'v_proj', 'up_proj', 'down_proj']
# group_by_length: False
# wandb_project:
# wandb_run_name:
# wandb_watch:
# wandb_log_model:
# resume_from_checkpoint: None
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 472/472 [00:00<00:00, 4.16MB/s]
# pytorch_model.bin.index.json: 26.8kB [00:00, 87.2MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0% 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0% 630k/9.98G [00:01<6:08:37, 451kB/s]
# pytorch_model-00001-of-00002.bin:   0% 2.03M/9.98G [00:01<2:15:25, 1.23MB/s]
# pytorch_model-00001-of-00002.bin:   1% 136M/9.98G [00:02<01:28, 111MB/s]
# pytorch_model-00001-of-00002.bin:   2% 203M/9.98G [00:02<01:23, 118MB/s]
# pytorch_model-00001-of-00002.bin:  10% 1.01G/9.98G [00:02<00:10, 843MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.28G/9.98G [00:02<00:09, 889MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.48G/9.98G [00:03<00:11, 715MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.68G/9.98G [00:04<00:16, 499MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.09G/9.98G [00:04<00:10, 782MB/s]
# pytorch_model-00001-of-00002.bin:  23% 2.29G/9.98G [00:04<00:12, 596MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.49G/9.98G [00:07<00:29, 253MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.69G/9.98G [00:07<00:22, 322MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.82G/9.98G [00:07<00:19, 376MB/s]
# pytorch_model-00001-of-00002.bin:  30% 3.02G/9.98G [00:07<00:14, 481MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.16G/9.98G [00:07<00:15, 427MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.29G/9.98G [00:08<00:17, 388MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.43G/9.98G [00:08<00:18, 355MB/s]
# pytorch_model-00001-of-00002.bin:  35% 3.49G/9.98G [00:09<00:24, 265MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.56G/9.98G [00:11<00:54, 119MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.76G/9.98G [00:11<00:31, 197MB/s]
# pytorch_model-00001-of-00002.bin:  40% 3.96G/9.98G [00:11<00:20, 292MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.16G/9.98G [00:11<00:14, 408MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.30G/9.98G [00:12<00:11, 489MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4
B/s]
# pytorch_model-00002-of-00002.bin: 100% 3.50G/3.50G [00:11<00:00, 311MB/s]
# Downloading shards: 100% 2/2 [00:44<00:00, 22.14s/it]
# Loading checkpoint shards: 100% 2/2 [00:11<00:00,  5.80s/it]
# generation_config.json: 100% 137/137 [00:00<00:00, 1.50MB/s]
# tokenizer_config.json: 100% 207/207 [00:00<00:00, 2.44MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 1.08MB/s]
# special_tokens_map.json: 100% 72.0/72.0 [00:00<00:00, 757kB/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): CastOutputToFloat(
#     (0): Linear(in_features=4096, out_features=32000, bias=False)
#   )
# )
# DoRA init
# model.layers.0.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.0.self_attn.q_proj.lora_A.weight is trainable
# model.layers.0.self_attn.q_proj.lora_B.weight is trainable
# model.layers.0.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.0.self_attn.k_proj.lora_A.weight is trainable
# model.layers.0.self_attn.k_proj.lora_B.weight is trainable
# model.layers.0.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.0.self_attn.v_proj.lora_A.weight is trainable
# model.layers.0.self_attn.v_proj.lora_B.weight is trainable
# model.layers.0.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.0.mlp.up_proj.lora_A.weight is trainable
# model.layers.0.mlp.up_proj.lora_B.weight is trainable
# model.layers.0.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.0.mlp.down_proj.lora_A.weight is trainable
# model.layers.0.mlp.down_proj.lora_B.weight is trainable
# model.layers.1.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.1.self_attn.q_proj.lora_A.weight is trainable
# model.layers.1.self_attn.q_proj.lora_B.weight is trainable
# model.layers.1.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.1.self_attn.k_proj.lora_A.weight is trainable
# model.layers.1.self_attn.k_proj.lora_B.weight is trainable
# model.layers.1.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.1.self_attn.v_proj.lora_A.weight is trainable
# model.layers.1.self_attn.v_proj.lora_B.weight is trainable
# model.layers.1.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.1.mlp.up_proj.lora_A.weight is trainable
# model.layers.1.mlp.up_proj.lora_B.weight is trainable
# model.layers.1.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.1.mlp.down_proj.lora_A.weight is trainable
# model.layers.1.mlp.down_proj.lora_B.weight is trainable
# model.layers.2.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.2.self_attn.q_proj.lora_A.weight is trainable
# model.layers.2.self_attn.q_proj.lora_B.weight is trainable
# model.layers.2.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.2.self_attn.k_proj.lora_A.weight is trainable
# model.layers.2.self_attn.k_proj.lora_B.weight is trainable
# model.layers.2.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.2.self_attn.v_proj.lora_A.weight is trainable
# model.layers.2.self_attn.v_proj.lora_B.weight is trainable
# model.layers.2.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.2.mlp.up_proj.lora_A.weight is trainable
# model.layers.2.mlp.up_proj.lora_B.weight is trainable
# model.layers.2.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.2.mlp.down_proj.lora_A.weight is trainable
# model.layers.2.mlp.down_proj.lora_B.weight is trainable
# model.layers.3.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.3.self_attn.q_proj.lora_A.weight is trainable
# model.layers.3.self_attn.q_proj.lora_B.weight is trainable
# model.layers.3.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.3.self_attn.k_proj.lora_A.weight is trainable
# model.layers.3.self_attn.k_proj.lora_B.weight is trainable
# model.layers.3.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.3.self_attn.v_proj.lora_A.weight is trainable
# model.layers.3.self_attn.v_proj.lora_B.weight is trainable
# model.layers.3.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.3.mlp.up_proj.lora_A.weight is trainable
# model.layers.3.mlp.up_proj.lora_B.weight is trainable
# model.layers.3.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.3.mlp.down_proj.lora_A.weight is trainable
# model.layers.3.mlp.down_proj.lora_B.weight is trainable
# model.layers.4.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.4.self_attn.q_proj.lora_A.weight is trainable
# model.layers.4.self_attn.q_proj.lora_B.weight is trainable
# model.layers.4.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers
self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.28.self_attn.k_proj.lora_A.weight is trainable
# model.layers.28.self_attn.k_proj.lora_B.weight is trainable
# model.layers.28.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.28.self_attn.v_proj.lora_A.weight is trainable
# model.layers.28.self_attn.v_proj.lora_B.weight is trainable
# model.layers.28.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.28.mlp.up_proj.lora_A.weight is trainable
# model.layers.28.mlp.up_proj.lora_B.weight is trainable
# model.layers.28.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.28.mlp.down_proj.lora_A.weight is trainable
# model.layers.28.mlp.down_proj.lora_B.weight is trainable
# model.layers.29.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.29.self_attn.q_proj.lora_A.weight is trainable
# model.layers.29.self_attn.q_proj.lora_B.weight is trainable
# model.layers.29.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.29.self_attn.k_proj.lora_A.weight is trainable
# model.layers.29.self_attn.k_proj.lora_B.weight is trainable
# model.layers.29.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.29.self_attn.v_proj.lora_A.weight is trainable
# model.layers.29.self_attn.v_proj.lora_B.weight is trainable
# model.layers.29.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.29.mlp.up_proj.lora_A.weight is trainable
# model.layers.29.mlp.up_proj.lora_B.weight is trainable
# model.layers.29.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.29.mlp.down_proj.lora_A.weight is trainable
# model.layers.29.mlp.down_proj.lora_B.weight is trainable
# model.layers.30.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.30.self_attn.q_proj.lora_A.weight is trainable
# model.layers.30.self_attn.q_proj.lora_B.weight is trainable
# model.layers.30.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.30.self_attn.k_proj.lora_A.weight is trainable
# model.layers.30.self_attn.k_proj.lora_B.weight is trainable
# model.layers.30.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.30.self_attn.v_proj.lora_A.weight is trainable
# model.layers.30.self_attn.v_proj.lora_B.weight is trainable
# model.layers.30.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.30.mlp.up_proj.lora_A.weight is trainable
# model.layers.30.mlp.up_proj.lora_B.weight is trainable
# model.layers.30.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.30.mlp.down_proj.lora_A.weight is trainable
# model.layers.30.mlp.down_proj.lora_B.weight is trainable
# model.layers.31.self_attn.q_proj.weight_m_wdecomp.weight is trainable
# model.layers.31.self_attn.q_proj.lora_A.weight is trainable
# model.layers.31.self_attn.q_proj.lora_B.weight is trainable
# model.layers.31.self_attn.k_proj.weight_m_wdecomp.weight is trainable
# model.layers.31.self_attn.k_proj.lora_A.weight is trainable
# model.layers.31.self_attn.k_proj.lora_B.weight is trainable
# model.layers.31.self_attn.v_proj.weight_m_wdecomp.weight is trainable
# model.layers.31.self_attn.v_proj.lora_A.weight is trainable
# model.layers.31.self_attn.v_proj.lora_B.weight is trainable
# model.layers.31.mlp.up_proj.weight_m_wdecomp.weight is trainable
# model.layers.31.mlp.up_proj.lora_A.weight is trainable
# model.layers.31.mlp.up_proj.lora_B.weight is trainable
# model.layers.31.mlp.down_proj.weight_m_wdecomp.weight is trainable
# model.layers.31.mlp.down_proj.lora_A.weight is trainable
# model.layers.31.mlp.down_proj.lora_B.weight is trainable
# Downloading data files: 100% 1/1 [00:00<00:00, 8848.74it/s]
# Extracting data files: 100% 1/1 [00:00<00:00, 1124.78it/s]
# Generating train split: 170420 examples [00:01, 155446.11 examples/s]
# trainable params: 28925952 || all params: 6767341568 || trainable%: 0.4274344912155615
# Map: 100% 170300/170300 [03:06<00:00, 911.10 examples/s]
# Map: 100% 120/120 [00:00<00:00, 918.40 examples/s]
# 2026-01-15 23:13:16.025403: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768518796.043887    4554 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768518796.049317    4554 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768518796.064325    4554 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768518796.064351    4554 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768518796.064354    4554 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768518796.064357    4554 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# /usr/local/lib/python3.12/dist-packages/accelerate/accelerator.py:449: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# {'loss': 3.0344, 'learning_rate': 2e-05, 'epoch': 0.0}
# {'loss': 2.63, 'learning_rate': 4e-05, 'epoch': 0.0}
# {'loss': 1.7859, 'learning_rate': 6e-05, 'epoch': 0.0}
# {'loss': 1.2865, 'learning_rate': 8e-05, 'epoch': 0.0}
# {'loss': 1.127, 'learning_rate': 0.0001, 'epoch': 0.0}
# {'loss': 0.9944, 'learning_rate': 0.00012, 'epoch': 0.01}
# {'loss': 1.0237, 'learning_rate': 0.00014, 'epoch': 0.01}
# {'loss': 0.9886, 'learning_rate': 0.00016, 'epoch': 0.01}
#   0% 80/31932 [02:03<14:26:15,  1.63s/it]
#   0% 0/15 [00:00<?, ?it/s]
#  13% 2/15 [00:00<00:02,  5.18it/s]
#  20% 3/15 [00:00<00:02,  4.06it/s]
#  27% 4/15 [00:01<00:03,  3.45it/s]
#  33% 5/15 [00:01<00:03,  3.09it/s]
#  40% 6/15 [00:01<00:02,  3.31it/s]
#  47% 7/15 [00:02<00:02,  3.17it/s]
#  53% 8/15 [00:02<00:02,  2.96it/s]
#  60% 9/15 [00:02<00:02,  2.84it/s]
#  67% 10/15 [00:03<00:01,  2.76it/s]
#  73% 11/15 [00:03<00:01,  2.97it/s]
#  80% 12/15 [00:03<00:01,  2.93it/s]
#  87% 13/15 [00:04<00:00,  2.99it/s]
#  93% 14/15 [00:04<00:00,  3.08it/s]
# 100% 15/15 [00:04<00:00,  2.98it/s]
# {'eval_loss': 0.9573208689689636, 'eval_runtime': 5.2212, 'eval_samples_per_second': 22.983, 'eval_steps_per_second': 2.873, 'epoch': 0.01}
#
#   0% 80/31932 [02:09<14:26:15,  1.63s/it]
# {'loss': 0.9391, 'learning_rate': 0.00018, 'epoch': 0.01}
# {'loss': 0.9488, 'learning_rate': 0.0002, 'epoch': 0.01}
# {'loss': 0.9757, 'learning_rate': 0.00019993717014325207, 'epoch': 0.01}
# {'loss': 0.9453, 'learning_rate': 0.00019987434028650417, 'epoch': 0.01}
# {'loss': 0.9849, 'learning_rate': 0.00019981151042975623, 'epoch': 0.01}
#   0% 133/31932 [03:31<14:14:23,  1.61s/it]Traceback (most recent call last):
#   File "/content/DoRA/commonsense_reasoning/finetune.py", line 384, in <module>
#     fire.Fire(train)
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 141, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 475, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fire/core.py", line 691, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/DoRA/commonsense_reasoning/finetune.py", line 349, in train
#     trainer.train(resume_from_checkpoint=resume_from_checkpoint)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 1537, in train
#     return inner_training_loop(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 1854, in _inner_training_loop
#     tr_loss_step = self.training_step(model, inputs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 2732, in training_step
#     self.accelerator.backward(loss)
#   File "/usr/local/lib/python3.12/dist-packages/accelerate/accelerator.py", line 1962, in backward
#     self.scaler.scale(loss).backward(**kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 625, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 354, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 841, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   0% 133/31932 [03:32<14:06:08,  1.60s/it]
# [W115 23:16:54.952954046 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())

# %%
# !nvidia-smi
# Out:
# Thu Jan 15 23:04:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ###Evaluation

# %%
# !bash llama_7B_Dora_eval.sh ./finetuned_result/llama_dora_r16 0
# Out:
# tee: ./finetuned_result/llama_dora_r32/boolq.txt: No such file or directory
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Traceback (most recent call last):
#   File "/content/DoRA/commonsense_reasoning/commonsense_evaluate.py", line 20, in <module>
#     from peft import PeftModel
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/__init__.py", line 30, in <module>
#     from .mapping import MODEL_TYPE_TO_PEFT_MODEL_MAPPING, PEFT_TYPE_TO_CONFIG_MAPPING, get_peft_config, get_peft_model
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/mapping.py", line 25, in <module>
#     from .peft_model import (
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/peft_model.py", line 40, in <module>
#     from .tuners import LoraModel, BottleneckModel, PrefixEncoder, PromptEmbedding, PromptEncoder, DoraModel
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/tuners/__init__.py", line 19, in <module>
#     from .dora import DoraConfig, DoraModel
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/tuners/dora.py", line 44, in <module>
#     import bitsandbytes as bnb
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/__init__.py", line 19, in <module>
#     from .backends.default import ops as default_ops
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/default/ops.py", line 362, in <module>
#     @_try_torch_compile
#      ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/default/ops.py", line 35, in _try_torch_compile
#     return decorator(func)
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/default/ops.py", line 19, in decorator
#     compiled_fn = torch.compile(fn, **compile_kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2640, in compile
#     return torch._dynamo.optimize(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 1263, in optimize
#     return _optimize(rebuild_ctx, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 1338, in _optimize
#     backend = get_compiler_fn(backend)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 1103, in get_compiler_fn
#     from .repro.after_dynamo import wrap_backend_debug
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 33, in <module>
#     from torch._dynamo.debug_utils import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/debug_utils.py", line 43, in <module>
#     from torch._dynamo.testing import rand_strided
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/testing.py", line 33, in <module>
#     from torch._dynamo.backends.debugging import aot_eager
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/backends/debugging.py", line 34, in <module>
#     from functorch.compile import min_cut_rematerialization_partition
#   File "/usr/local/lib/python3.12/dist-packages/functorch/compile/__init__.py", line 2, in <module>
#     from torch._functorch.aot_autograd import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/aot_autograd.py", line 154, in <module>
#     from .partitioners import default_partition
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/partitioners.py", line 44, in <module>
#     from ._activation_checkpointing.graph_info_provider import GraphInfoProvider
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_activation_checkpointing/graph_info_provider.py", line 3, in <module>
#     import networkx as nx
#   File "/usr/local/lib/python3.12/dist-packages/networkx/__init__.py", line 19, in <module>
#     from networkx import utils
#   File "/usr/local/lib/python3.12/dist-packages/networkx/utils/__init__.py", line 8, in <module>
#     from networkx.utils.backends import *
#   File "/usr/local/lib/python3.12/dist-packages/networkx/utils/backends.py", line 102, in <module>
#     backends = _get_backends("networkx.backends")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/networkx/utils/backends.py", line 69, in _get_backends
#     items = entry_points(group=group)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/__init__.py", line 913, in entry_points
#     return EntryPoints(eps).select(**params)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/__init__.py", line 911, in <genexpr>
#     dist.entry_points for dist in _unique(distributions())
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/_itertools.py", line 16, in unique_everseen
#     k = key(element)
#         ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/__init__.py", line 834, in _normalized_name
#     pass_none(Prepared.normalize)(self._name_from_stem(stem))
#   File "/usr/lib/python3.12/importlib/metadata/_functools.py", line 102, in wrapper
#     return func(param, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/metadata/__init__.py", line 762, in normalize
#     return re.sub(r"[-_.]+", "-", name).lower().replace('-', '_')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/re/__init__.py", line 186, in sub
#     return _compile(pattern, flags).sub(repl, string, count)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# tee: ./finetuned_result/llama_dora_r32/piqa.txt: No such file or directory
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Loading checkpoint shards:   0% 0/2 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/DoRA/commonsense_reasoning/commonsense_evaluate.py", line 346, in <module>
#     main()
#   File "/content/DoRA/commonsense_reasoning/commonsense_evaluate.py", line 83, in main
#     tokenizer, model = load_model(args)
#                        ^^^^^^^^^^^^^^^^
#   File "/content/DoRA/commonsense_reasoning/commonsense_evaluate.py", line 254, in load_model
#     model = AutoModelForCausalLM.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py", line 566, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 3694, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 4079, in _load_pretrained_model
#     state_dict = load_state_dict(shard_file)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 519, in load_state_dict
#     return torch.load(checkpoint_file, map_location=map_location)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1521, in load
#     return _load(
#            ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2122, in _load
#     result = unpickler.load()
#              ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_weights_only_unpickler.py", line 535, in load
#     self.append(self.persistent_load(pid))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2086, in persistent_load
#     typed_storage = load_tensor(
#                     ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2039, in load_tensor
#     zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)
# KeyboardInterrupt
# ^C

# %% [markdown]
# ### Fine tune and eval on LLama2 and LLama3 7B

# %%
# %cd /content/DoRA/commonsense_reasoning
# llama2 7B rank 16 alpha 64
# !bash llama2_7B_DoRA.sh 16 64 ./finetuned_result/llama_2_r16_lr2e-4 0

# llama3 7B rank 16 alpha 64
# !bash llama3_8B_DoRA.sh 16 64 ./finetuned_result/llama_3_r16_lr1e-4 0
# Out:
# /content/DoRA/commonsense_reasoning
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Traceback (most recent call last):
#   File "/content/DoRA/commonsense_reasoning/finetune.py", line 25, in <module>
#     from peft import (  # noqa: E402
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/__init__.py", line 30, in <module>
#     from .mapping import MODEL_TYPE_TO_PEFT_MODEL_MAPPING, PEFT_TYPE_TO_CONFIG_MAPPING, get_peft_config, get_peft_model
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/mapping.py", line 25, in <module>
#     from .peft_model import (
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/peft_model.py", line 40, in <module>
#     from .tuners import LoraModel, BottleneckModel, PrefixEncoder, PromptEmbedding, PromptEncoder, DoraModel
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/tuners/__init__.py", line 19, in <module>
#     from .dora import DoraConfig, DoraModel
#   File "/content/DoRA/commonsense_reasoning/peft/src/peft/tuners/dora.py", line 44, in <module>
#     import bitsandbytes as bnb
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/__init__.py", line 19, in <module>
#     from .backends.default import ops as default_ops
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/default/ops.py", line 362, in <module>
#     @_try_torch_compile
#      ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/default/ops.py", line 35, in _try_torch_compile
#     return decorator(func)
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/default/ops.py", line 19, in decorator
#     compiled_fn = torch.compile(fn, **compile_kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2640, in compile
#     return torch._dynamo.optimize(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 1263, in optimize
#     return _optimize(rebuild_ctx, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 1338, in _optimize
#     backend = get_compiler_fn(backend)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 1103, in get_compiler_fn
# ^C
# ^C
# ^C
# ^C
